# %% [markdown]
# ## Notes
# seems to be "converging" after 10000 iterations...

# %%
import os
os.environ["OMP_NUM_THREADS"] = '32'
import numpy as np
import scipy.sparse as sp
import matplotlib.pyplot as plt
import math
import sys
sys.path.append('../')
from pyfd3d import pyfd3d
from pyMKL import pardisoSolver
import pyfd3d.fd3d as fd3d
from scipy.sparse.linalg import qmr, bicgstab

# %%
Nz = 60
Npml = np.array([0,0,10])

# %%
L0 = 1e-6
## specify slab plane
xrange = yrange = np.array([-0.5,0.5])
zrange = [-1,1];
radius = 0.25
Nx = Ny = 40

x = np.linspace(xrange[0], xrange[1], Nx)
y = np.linspace(yrange[0], yrange[1], Ny)
z = np.linspace(zrange[0], zrange[1], Nz)
xx,yy = np.meshgrid(x,y)

slab_plane = 4*np.ones((Nx,Ny))

slab_plane[xx**2+yy**2<radius**2] = 1
plt.imshow(slab_plane)

# %%
## integrate slab structure into 3D grid
eps_r = np.ones((Nx,Ny,Nz))
N = [Nx,Ny,Nz]

# %%
print(eps_r.shape)
for k in range(25,40):
    eps_r[:,:,k] = slab_plane
# Out:
# (40, 40, 60)

# %%
Jz = np.zeros(N); 
Jy = np.zeros(N);
Jx = np.zeros(N);
Jx[:,:,15] = 1;
Jy[:,:,15] = 1
eps_r_tensor_dict = {
    'eps_xx': eps_r,
    'eps_yy': eps_r.copy(),
    'eps_zz': eps_r.copy(),
}
JCurrentVector = {
    'Jx': Jx,
    'Jy': Jy,
    'Jz': Jz
}

# %%
wvlen = 0.51;
print(L0, xrange, yrange, zrange)

A,b, Ch = fd3d.curlcurlE(L0, 
                         wvlen, 
                         xrange, 
                         yrange, 
                         zrange, 
                         eps_r_tensor_dict, 
                         JCurrentVector,Npml, 
                         s = -1
                        )
# Out:
# 1e-06 [-0.5  0.5] [-0.5  0.5] [-1, 1]
# (288000,)

# %% [markdown]
# ## Notes
# 1. hmmm, seems like bicg-stab fails on this system?

# %%
## ilu preconditioner?
from scipy.sparse.linalg import spilu

# %%
# %%time
#x, info = qmr(A, b, maxiter = 2000)
x, info = qmr(A,b, maxiter = 10000);
print(info)
# Out:
# 10000
# CPU times: user 45min 34s, sys: 2min 40s, total: 48min 15s
# Wall time: 6min 51s

# %%
print(info) #system did not converge?
# Out:
# 10000

# %%
y = Ch@x
print(y.shape, A.shape)
# Out:
# (288000,) (288000, 288000)

# %%
M = np.prod(N);
Ex = x[0:M].reshape(N, order = 'F');
Ey = x[M:2*M].reshape(N, order = 'F')
Ez = x[2*M:].reshape(N, order = 'F')

Hx =  y[0:M].reshape(N, order = 'F')
Hy =  y[M:2*M].reshape(N, order = 'F')
Hz =  y[2*M:].reshape(N, order = 'F')

# %%
for i in range(0,N[0],2):
    plt.figure()
    #plt.imshow(np.real(Ey[:,:,i]), cmap = 'RdBu')
    plt.imshow(np.abs(Ex[:,i,:]), cmap = 'hot')

    #plt.clim(0,0.5e-2)
    plt.colorbar()

# %%
for i in range(0,N[0],2):
    plt.figure()
    #plt.imshow(np.real(Ey[:,:,i]), cmap = 'RdBu')
    plt.imshow(np.real(Ex[:,i,:]), cmap = 'RdBu')

    plt.clim(-20,20)
    plt.colorbar()

# %%
for i in range(0,N[-1],2):
    plt.figure()
    #plt.imshow(np.real(Ey[:,:,i]), cmap = 'RdBu')
    plt.imshow(np.real(Ex[:,:,i]), cmap = 'RdBu')

    plt.colorbar()
# Out:
# /var/folders/f8/nqg1jnk548j7c367bl0lgl0r0000gn/T/ipykernel_46746/3843397456.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
print(np.linalg.norm(A@x-b)/np.linalg.norm(b))

plt.plot(np.abs(A@x))
plt.plot(np.abs(b))
# Out:
# 0.003647561168661815

# %%
print(np.allclose(A@x, b))
# Out:
# False

# %%
plt.plot(np.abs(x))

# %% [markdown]
# ## pardiso solve (careful)
#
# I just want to check to see...the direct solver should be relatively robust even if it busts the memory

# %%
#try solving with pardiso
# pardiso doesn't even really work with this FDFD matrix, which is odd...honestly very very odd

## for vaccum, mtype=13, complex, non-symmetric
# mtype=6 is complex symmetric
pSolve = pardisoSolver(A, mtype=13)

# %%
# %%time
pSolve.factor()
# Out:
# OMP: Info #271: omp_get_nested routine deprecated, please use omp_get_max_active_levels instead.
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# CPU times: user 1h 33min 10s, sys: 1min 42s, total: 1h 34min 52s
# Wall time: 15min 5s

# %%
x0 = pSolve.solve(np.imag(b))

# %%
plt.plot(abs(x0))
plt.plot(abs(x), alpha = 0.4)

# %%
plt.plot(np.abs(A@x0))
plt.plot(np.abs(A@x))

# %%
## interesting, some phase mismatch between real and imaginary parts of direct and iterative solutoin?
plt.plot(np.real(x0))
plt.plot(np.real(x))

# %%
plt.plot(np.imag(x0))
plt.plot(np.real(x))
